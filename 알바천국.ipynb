# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

for i in range(1, 10):
    URL_1 = "http://www.alba.co.kr/story/albastory/StoryList.asp?page="+str(i)+"&pagesize=20&btypecd=101&schType=&schText=&schParam1=&schParam2=&boardType=1&OrderBy=regdt"
    html = requests.get(URL_1).text
    soup = BeautifulSoup(html, 'html.parser')
    for tag in soup.select('#Container .formList .title strong'):
            print(tag.text)
# Out:
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [서비스 기타]
# 대박 부업 알바 봐주세요
#
# [편의점]
# 부산 기장 CU 편의점 절대 가지마세요
#
# [PC방]
# pc방 알바 그만둠
#
# 진짜 진상이고 뭐고 다 괜찮은데 제발 돈만 제대로 줬으면 좋겠다..
#
# [영화·공연·전시]
# 무대설치회사 ＇ㅈㅇㅁㄷ＇ 절대 가지마세요
#
# [커피전문점]
# 해운대 더××
#
# [편의점]
# 편의점 이런적 있나요?
#
# [포장·조립]
# 성서 4차 휴대폰 공장 어디가 좋아요?
#
# [매장관리]
# 월급계산좀 부탁드려요
#
# [헤어·피부·미용·애견]
# 마사지란 무엇인가 정확히 알고 취업하기
#
# [포장·조립]
# 인천 간석아웃소싱. 이거 내가 잘못한겁니까?
#
# 일 조건은 마음에드는데
#
# [매장관리]
# 본사는 좋은데 이 회사가 입점한 매장이 별로에요ㅠㅠ
#
# [편의점]
# 피로도가 금방오나요???
#
# 친구랑 동반입사..
#
# [편의점]
# 편의점 최저임금 안주는거 왜케 당당하냐
#
# 청소년 야간 알바
#
# 꿀알바맞나용
#
# [영업·마케팅]
# 기업섭외 업무 하지 마세요
#
# 그만둘때 핑계 추천해주세요...
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [매장관리]
# 외국인  국적 대만  f5 영구비자（40대)
#
# [간호·병원·의료]
# 관악에 있는 조금 큰 약국 다니고 있어요..
#
# [조리·주방보조]
# 광주 운암동
#
# 30대는 어디로 일하러 가야하나요?
#
# [공사현장]
# 용역업체서 숙식제공까지하던데 일 할만한가요?
#
# [서빙·주방 기타]
# 불규칙한 업무시간
#
# 알바 면접 결과 언제 나올까요..?
#
# [예체능·레포츠]
# 더러운데서 짤려서 기분이 더더러워요ㅠ
#
# [생산·기능·운전·배달]
# 공고를 올리질 말던가
#
# [음향·조명·무대]
# 안내데스크 + 연출
#
# [의류·잡화]
# 월급 못 받았어요
#
# [베이커리]
# 제과점 직원 채용 매번 똑같은 곳만 나옵니다
#
# [편의점]
# 최저시급
#
# [스크린골프]
# 알바1년..퇴직금주길싫어서짤라버림
#
# [생산·기능 기타]
# 대구 생산직(공장)어디가조아요?
#
# 제주 승마장 알바어떤가요?
#
# [편의점]
# 제가 편의점 알바하고있는데요...
#
# [기타매장]
# 놀면 빛쟁이
#
# [커피전문점]
# 커피집알바면접시 팁
#
# [생산·기능 기타]
# 구미 요새 어떤가요?
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [포장·조립]
# 공장사장들 자주 짜를때 대처법
#
# [매장관리]
# 화장품 매장 알바
#
# [뷰티·헬스스토어]
# 오래 일한다고 하고 일찍 그만두면
#
# [배달]
# 배달알바
#
# 첫 알바 면접인데 옷을 어떻게 입어야되죠
#
# 아직도 최저임금안주는곳이있네요. ;
#
# [생산·기능·운전·배달]
# 요즘아웃소싱
#
# 첫 알바
#
# 면접 연락이 왔어요
#
# 박람회
#
# [음식점]
# 이럴땐 어쩌야 되나요
#
# [쇼핑몰·오픈마켓]
# 강릉 거상 쇼핑몰 진짜 있는건지 아시는분?ㅠ
#
# [외국어·어학원]
# 일본인 직업 추펀좀해주세요
#
# [음식점]
# 이런경우는 어쩌죠 ㅠㅠ
#
# 도대체 해외 카지노 그게 먼가요 장기 떼먹는건가요
#
# [베이커리]
# 창원 상남동 M****베이커리
#
# [서비스·미디어]
# 돈 없는 채로 산다는건
#
# [청과·축산·수산·농산]
# 월급계산좀....
#
# [청과·축산·수산·농산]
# 도대체 이력서는 왜접는가요
#
# [PC방]
# 이수역 근처 피시방
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [편의점]
# 개인적으로 생각하는 편의점 면접 팁
#
# [DVD·만화·멀티방]
# cctv어떻게느끼나요?전이일후극혐이네요
#
# [제조·가공]
# 생산직 간부 조장이 자꾸 ㅣ밑에 사원보고 먹을껄 바래요
#
# [생산·기능·운전·배달]
# 오산에 있는 마스크팩 공장 ...
#
# [일반주점·호프]
# 부산 사하구 장림 호프집 ㄲㄹㅃ  사장이 ㄸㄹㅇ입니다
#
# [백화점·면세점]
# 백회점일에서짤림
#
# [음식점]
# 창원 카ㅁㅌㅋ***,마ㅁㄷ 사장 같음 참고하세요
#
# 공고 올릴 수 있는곳이 어딨나요?
#
# [매장관리]
# 알바 세개중 머가 나을까여??
#
# [PC방]
# 피시방 아르바이트
#
# pc방 알바 vs 우리매장
#
# [편의점]
# 추석연휴인데 다일하셨나요?  Feat.진상
#
# [음식점]
# 다대포해수욕장 옆 아ㄹㄹ알바하지마세요 알바비 제때안줌
#
# [커피전문점]
# 여기서라도 한풀이 해봅니다ㅇㅅㅇ...
#
# 내가할수있는일
#
# [보안·경호·경비]
# 아파트 경비업체에서 일하는데 임금이 이상하네요ㅡㅡ
#
# 공장 알바 구하는 법
#
# 채용정보 보고서 문자보내고 전화도 몇번이나 걸었는데 답을 안하네
#
# [생산·기능 기타]
# 요즘 이상한 문자들이 옵니다.
#
# 공장이나 현장보조 하려는데
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [편의점]
# 미성년자 편의점 알바 질문
#
# 2년째 알바 못구하는중..
#
# [음식점]
# 다좋은데 매장이 바빠지기 시작하면...
#
# 명절때 부려먹는 시퀴들이!
#
# [편의점]
# 수치심
#
# [편의점]
# 공고글이 계속 올라오는 곳은 역시나 문제가 있는 곳이네요
#
# [매장관리]
# 급여 맞는건지..저좀 도와주시겠어요?ㅠㅠ
#
# 택배기사 구인글보면은
#
# [PC방]
# 피시방 일한 급여
#
# [매장관리]
# 업체쪽으로 안심번호로전화를 드렸는데 제번호는 그대로 뜨나요???
#
# [커피전문점]
# 팔당 ㅌㄴ커피
#
# 알바채용광고글 ㅡㅡ;;
#
# [음식점]
# 서동  돼지oo 여기 사장최악
#
# [커피전문점]
# 주휴수당
#
# [음식점]
# 추석알바하려고 했는데 전날 오지 말라고 통보하는 사장....
#
# [매장관리]
# 줄건주고 일시켜요
#
# [기타매장]
# 뭐 어쩌란거지 ㅋㅋ
#
# [음식점]
# 알바하다가 잘린 적은 처음이네
#
# [커피전문점]
# 오늘 카페 면접을 보러가는데요...
#
# 가끔 피씨방 구인글 쓰시는 분들 보면ㅋㅋㅋㅋㅋ
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# 치과에서 일해보신분 ㅠㅠ
#
# [편의점]
# 편의점 최저시급 쳐주는곳 1도없네
#
# [물류·창고관리]
# 야간물류알바 정말 힘듭니다.
#
# [사무보조·문서작성]
# 안산 한대앞 모델하우스 더x테x스
#
# 님들도 추석때  알바하시나요??
#
# [사무·회계]
# 수원 사무직 공고 기준이 뭘까요
#
# [운반·이사]
# 서울역 책자 가지마세요. 여러분
#
# [커피전문점]
# 퇴직금
#
# 시급높네
#
# [커피전문점]
# 청소년단기알바
#
# 17살 청소년 알바
#
# [음식점]
# 잔반을 알바생 식사로 주는게 정상인가요;;;;;
#
# [음식점]
# 알바짤렷는데
#
# [생산·기능 기타]
# 인천아웃소싱..
#
# [퀵서비스·택배]
# 고3 생일 안지난 미성년자 입니다
#
# [숙박·호텔·리조트]
# (경험담) 게스트하우스 면접
#
# [음식점]
# 피자가게인데 술파는곳이면 고3 알바 안되는가요??
#
# 건설현장 근로자 임금에서 10%를 떼어가는 것은 위법입니다
#
# [서빙·주방]
# 알바 월급 빨리 안 주는 이유
#
# [PC방]
# 포항 라*온 피시방 청소만 하다가 온 내이야기
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [대형마트]
# 오늘 너무 어이 없는 일 당했네요
#
# [제조·가공]
# 단기알바 후기 어이없이 짤림
#
# [음식점]
# 고3 식당주방알바 면접가는데 복장 어떻게 입어야하나요??
#
# [청소·미화]
# 야간 환경미화원
#
# [매장관리]
# 급여계산기에
#
# [음식점]
# 알바 갑자기 잘림
#
# [음식점]
# 경력만 보면 첫시작하는 20대들은 어떻게 경력을 쌓아라는 건지..
#
# 이거 어떤 알바인가요?
#
# [베이커리]
# 빵집말고 다른델 해야하나 자격증도 이미 다 땄는데
#
# [퀵서비스·택배]
# 이번주부터는 택배하지 마세요.
#
# [물류·창고관리]
# 과일상자분류택배작업 이게 정확히 무슨일이죠?
#
# 야간 알바가 시급1.5배 받는다는 소리를 들었는데
#
# [청소·미화]
# 무례한 회사
#
# [서비스 기타]
# 여태 만났던 악덕사장들 3명 공통점이 전부 비슷해요....
#
# 부산 청소년
#
# [이벤트]
# 한성백제문화제 행사 알바
#
# 시간 약속을 못지킬거 같으면 전화나 문자라도 넣어주세요..
#
# 이거 뭘까요?
#
# 면접도안보고 출근하는곳에서 일해보신분있나요?
#
# 사장님들 특히 편의점 악덕사장님들
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [편의점]
# 알바생
#
# 홍콩땡땡
#
# [음식점]
# 인천 동암 소곱창집
#
# [편의점]
# 일부러 그러는걸까요?
#
# 풀타임으로해서 최저도안줄거면 그냥 니들이 다하세요
#
# [생산·기능·운전·배달]
# 공장 생산직 어떤가요
#
# [편의점]
# 갑의횡포
#
# [편의점]
# 야간수당
#
# ㅇㅌ짐 거기 가지마세요
#
# [생산·기능·운전·배달]
# 공장일은 처음이라..ㅜㅜ
#
# [서비스 기타]
# 몇군데 면접보고 난후
#
# [고객상담·영업·리서치]
# 직원문제일까 회사책임일까
#
# [뷰티·헬스스토어]
# 너무하는거같음
#
# [커피전문점]
# 고용주가 연락을 안받아요
#
# [서비스·미디어]
# 님들이일해요...말아요?...
#
# [품질검사·관리]
# 구미생산직이요ㅜㅠㅠ
#
# 고딩 첫알바 구하는데
#
# [DVD·만화·멀티방]
# VR매장 후기좀 들려주세요~
#
# [아이스크림·생과일]
# 베라알바 면접가는데
#
# [의류·잡화]
# 직원 구하는 글올라왔길래
# 개별 구인정보 게시글 이용제한 방침 안내
# 온라인다단계 주의하세요!
# 복조리 판매 조심하세요!
# 고소득 재택알바, 그것이 알고싶다.
# 대포통장사기, 아직도 이런 일이?
#
# [IT·디자인]
# 정리해고당햇어요.
#
# [생산·기능·운전·배달]
# 택배알바 운송알바 해보신분 계신가요?
#
# [물류·창고관리]
# 택배물류 2년넘게 햇는데 인천와서 다시알아보려 합니다
#
# [대형마트]
# 시급
#
# [간호·병원·의료]
# 이런 사람 밑에서 일하지 마세요.
#
# [매장관리]
# 허리디스크,완전심한거북목+목디스크있는사람이 할수있는일
#
# [음식점]
# 고기집에서 처음 알바합니다!
#
# [공사현장]
# 노가다는 왜 아침일찍 시작하는걸까요 ㅠ
#
# [보안·경호·경비]
# 마음에 드는곳 전화로 지원했더니....
#
# [제조·가공]
# 약속 어기고 안올거라면 지원하지 마세요
#
# [PC방]
# 피시방 아르바이트
#
# [서빙·주방]
# 수신발신정지폰으로알바가능?
#
# [사무·회계 기타]
# 무단 결근 급여지급 보류 (사직서 미제출)
#
# [노래방]
# 노래방알바 새벽에
#
# 미성년자여도 부모님만 동의하면 되는건가요?
#
# 부업
#
# [편의점]
# 편의점 수습기간에 5000원 주는것도 신고가능한가요?
#
# [포장·조립]
# 알바 뽑아 놓고...
#
# [서빙·주방]
# 일하고 싶은데...
#
# [음식점]
# 해고
